# %%
# Define a new cgraph
cgraph = {'WA': ['SA', 'NT'], 
          'Q': ['SA', 'NT', 'NSW'], 
          'T': [],
          'V': ['SA', 'NSW'], 
          'SA': ['WA', 'NT', 'Q', 'NSW','V'], 
          'NT': ['Q', 'WA', 'SA'], 
          'NSW': ['Q', 'V', 'SA']}

# %%
import random
def get_color(node, rv, cg):
    # CODE
    # check rv[node] is empty or not when no color availabe
    # return 'no color'
    if len(rv[node])==0:
        return 'no color'
    else:
        color = random.choice(rv[node])
        rv.pop(node)
        # update remaining values for neihbouring node
        adjList = cg[node]
        for adj in adjList:
            if adj in rv.keys():
                rv[adj].remove(color)
        #print(adjList)
        return color

# %% [markdown]
# ## Highest Degree Node

# %%
# write a method to get the highest degree node
def get_hdnode(cg, solved):
    mnode = ''
    degree = -1
    for k in cg.keys():
        if len(cg[k])  > degree and k not in solved.keys():
            #print(k)
            degree = len(cg[k])
            mnode = k
    return mnode

# %% [markdown]
# Color the nodes using Highest degree heuristic

# %%
assigned = {} # store assignes variables with colors
remainingValues = {'WA': ['R','G','B'], 
                    'Q': ['R','G','B'],
                    'T': ['R','G','B'],
                    'V':  ['R','G','B'], 
                    'NT': ['R','G','B'],
                    'SA': ['R','G','B'],                    
                    'NSW': ['R','G','B']}


for i in range(len(cgraph)):
    # assign color to the highest degree node
    hdNode = get_hdnode(cgraph, assigned)
    color = get_color(hdNode, remainingValues, cgraph)
    # CODE
    # check if 'no color' is returned
    # print failure
    if color=='no color':
        print('Failure')
    else:
        assigned[hdNode]= color
        print(remainingValues)
        print(assigned)
# Out:
# {'WA': ['G', 'B'], 'Q': ['G', 'B'], 'T': ['R', 'G', 'B'], 'V': ['G', 'B'], 'NT': ['G', 'B'], 'NSW': ['G', 'B']}
# {'SA': 'R'}
# {'WA': ['G', 'B'], 'T': ['R', 'G', 'B'], 'V': ['G', 'B'], 'NT': ['B'], 'NSW': ['B']}
# {'SA': 'R', 'Q': 'G'}
# {'WA': ['G'], 'T': ['R', 'G', 'B'], 'V': ['G', 'B'], 'NSW': ['B']}
# {'SA': 'R', 'Q': 'G', 'NT': 'B'}
# {'WA': ['G'], 'T': ['R', 'G', 'B'], 'V': ['G']}
# {'SA': 'R', 'Q': 'G', 'NT': 'B', 'NSW': 'B'}
# {'T': ['R', 'G', 'B'], 'V': ['G']}
# {'SA': 'R', 'Q': 'G', 'NT': 'B', 'NSW': 'B', 'WA': 'G'}
# {'T': ['R', 'G', 'B']}
# {'SA': 'R', 'Q': 'G', 'NT': 'B', 'NSW': 'B', 'WA': 'G', 'V': 'G'}
# {}
# {'SA': 'R', 'Q': 'G', 'NT': 'B', 'NSW': 'B', 'WA': 'G', 'V': 'G', 'T': 'B'}

# %% [markdown]
# ## Minimum Remaining Value

# %%
# define a method to select a node by MRV
def get_MRVnode(rv, sol):
    # CODE
    #implement the logic on remainingValues list
    minvnode=''
    mrvalue=4
    for i in rv.keys():
        if len(rv[i])<mrvalue and i not in sol.keys():
                mrvalue=len(rv[i])
                minvnode=i
    return minvnode

# %% [markdown]
# Color the nodes using MRV heuristic

# %%
assigned = {}

remainingValues = {'WA': ['R','G','B'], 
                    'Q': ['R','G','B'],
                    'T': ['R','G','B'],
                    'V':  ['R','G','B'], 
                    'NT': ['R','G','B'],
                    'SA': ['R','G','B'],                    
                    'NSW': ['R','G','B']}

for i in range(len(cgraph)):
    # assign color to the highest degree node
    mrvNode = get_MRVnode(remainingValues, assigned)
    color = get_color(mrvNode, remainingValues, cgraph)
    # CODE
    # check if 'no color' is returned
    # print failure
    if color=='no color':
        print('Failure')
    else:
        assigned[mrvNode]= color
        print(remainingValues)
        print(assigned)
# Out:
# {'Q': ['R', 'G', 'B'], 'T': ['R', 'G', 'B'], 'V': ['R', 'G', 'B'], 'NT': ['R', 'B'], 'SA': ['R', 'B'], 'NSW': ['R', 'G', 'B']}
# {'WA': 'G'}
# {'Q': ['R', 'G'], 'T': ['R', 'G', 'B'], 'V': ['R', 'G', 'B'], 'SA': ['R'], 'NSW': ['R', 'G', 'B']}
# {'WA': 'G', 'NT': 'B'}
# {'Q': ['G'], 'T': ['R', 'G', 'B'], 'V': ['G', 'B'], 'NSW': ['G', 'B']}
# {'WA': 'G', 'NT': 'B', 'SA': 'R'}
# {'T': ['R', 'G', 'B'], 'V': ['G', 'B'], 'NSW': ['B']}
# {'WA': 'G', 'NT': 'B', 'SA': 'R', 'Q': 'G'}
# {'T': ['R', 'G', 'B'], 'V': ['G']}
# {'WA': 'G', 'NT': 'B', 'SA': 'R', 'Q': 'G', 'NSW': 'B'}
# {'T': ['R', 'G', 'B']}
# {'WA': 'G', 'NT': 'B', 'SA': 'R', 'Q': 'G', 'NSW': 'B', 'V': 'G'}
# {}
# {'WA': 'G', 'NT': 'B', 'SA': 'R', 'Q': 'G', 'NSW': 'B', 'V': 'G', 'T': 'B'}

# %% [markdown]
# # Map of Chiitagong

# %% [markdown]
# ![Chattogram_Division_districts_map.png](attachment:Chattogram_Division_districts_map.png)

# %%
# map of Chittagong
cgraph = {'Chittagong' : ['Comilla','Bandarban'],
          'Comilla' :['Bandarban','Khagrachari','Noakhali'],
          'Feni' :['Rangamati','Chandpur','Chittagong'],
          'Noakhali' :['Bandarban','Comilla','Coxs Bazar'],
          'Chandpur' :['Bandarban','Rangamati','Chittagong','Comilla'],
          'Khagrachari' :['Rangamati','Khagrachari','Chittagong'],
          'Bandarban':['Khagrachari','Comilla','Chittagong'],
          'Rangamati':['Bandarban','Comilla','Khagrachari'],
          'Coxs Bazar' :['Comilla','Chandpur']}

# %%
import random
def get_color(node, rv, cg):
    # CODE
    # check rv[node] is empty or not when no color availabe
    # return 'no color'
    if len(rv[node])==0:
        return 'no color'
    else:
        color = random.choice(rv[node])
        rv.pop(node)
        # update remaining values for neihbouring node
        adjList = cg[node]
        for adj in adjList:
            if adj in rv.keys():
                rv[adj].remove(color)
        #print(adjList)
        return color

# %% [markdown]
# Highest Degree Node

# %%
# write a method to get the highest degree node
def get_hdnode(cg, solved):
    mnode = ''
    degree = -1
    for k in cg.keys():
        if len(cg[k])  > degree and k not in solved.keys():
            #print(k)
            degree = len(cg[k])
            mnode = k
    return mnode

# %% [markdown]
# Color the nodes using Highest degree heuristic

# %%
assigned = {} # store assignes variables with colors
remainingValues = {'Chittagong' :['R','G','B'],
                   'Comilla' :['R','G','B'],
                   'Feni' :['R','G','B'],
                   'Noakhali' :['R','G','B'],
                   'Chandpur' :['R','G','B'],
                   'Khagrachari' :['R','G','B'],
                   'Bandarban':['R','G','B'],
                   'Rangamati':['R','G','B'],
                   'Coxs Bazar':['R','G','B']}

for i in range(len(cgraph)):
    # assign color to the highest degree node
    hdNode = get_hdnode(cgraph, assigned)
    color = get_color(hdNode, remainingValues, cgraph)
    # CODE
    # check if 'no color' is returned
    # print failure
    if color=='no color':
        print('Failure')
    else:
        assigned[hdNode]= color
        print(remainingValues)
        print(assigned)
# Out:
# {'Chittagong': ['R', 'B'], 'Comilla': ['R', 'B'], 'Feni': ['R', 'G', 'B'], 'Noakhali': ['R', 'G', 'B'], 'Khagrachari': ['R', 'G', 'B'], 'Bandarban': ['R', 'B'], 'Rangamati': ['R', 'B'], 'Coxs Bazar': ['R', 'G', 'B']}
# {'Chandpur': 'G'}
# {'Chittagong': ['R', 'B'], 'Feni': ['R', 'G', 'B'], 'Noakhali': ['R', 'G'], 'Khagrachari': ['R', 'G'], 'Bandarban': ['R'], 'Rangamati': ['R', 'B'], 'Coxs Bazar': ['R', 'G', 'B']}
# {'Chandpur': 'G', 'Comilla': 'B'}
# {'Chittagong': ['B'], 'Noakhali': ['R', 'G'], 'Khagrachari': ['R', 'G'], 'Bandarban': ['R'], 'Rangamati': ['B'], 'Coxs Bazar': ['R', 'G', 'B']}
# {'Chandpur': 'G', 'Comilla': 'B', 'Feni': 'R'}
# {'Chittagong': ['B'], 'Khagrachari': ['R', 'G'], 'Bandarban': [], 'Rangamati': ['B'], 'Coxs Bazar': ['G', 'B']}
# {'Chandpur': 'G', 'Comilla': 'B', 'Feni': 'R', 'Noakhali': 'R'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-3920df76c157> in <module>
#      13     # assign color to the highest degree node
#      14     hdNode = get_hdnode(cgraph, assigned)
# ---> 15     color = get_color(hdNode, remainingValues, cgraph)
#      16     # CODE
#      17     # check if 'no color' is returned
#
# <ipython-input-13-dac3d7c0510b> in get_color(node, rv, cg)
#      13         for adj in adjList:
#      14             if adj in rv.keys():
# ---> 15                 rv[adj].remove(color)
#      16         #print(adjList)
#      17         return color
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# Minimum Remaining Value

# %%
# define a method to select a node by MRV
def get_MRVnode(rv, sol):
    # CODE
    #implement the logic on remainingValues list
    minvnode=''
    mrvalue=5
    for i in rv.keys():
        if len(rv[i])<mrvalue and i not in sol.keys():
                mrvalue=len(rv[i])
                minvnode=i
    return minvnode

# %%
assigned = {}

remainingValues = {'Chittagong' :['R','G','B'],
                   'Comilla' :['R','G','B'],
                   'Feni' :['R','G','B'],
                   'Noakhali' :['R','G','B'],
                   'Chandpur' :['R','G','B'],
                   'Khagrachari' :['R','G','B'],
                   'Bandarban':['R','G','B'],
                   'Rangamati':['R','G','B'],
                   'Coxs Bazar' :['R','G','B']}

for i in range(len(cgraph)):
    # assign color to the highest degree node
    mrvNode = get_MRVnode(remainingValues, assigned)
    color = get_color(mrvNode, remainingValues, cgraph)
    # CODE
    # check if 'no color' is returned
    # print failure
    if color=='no color':
        print('Failure')
    else:
        assigned[mrvNode]= color
        #print(remainingValues)
        print(assigned)
# Out:
# {'Chittagong': 'B'}
# {'Chittagong': 'B', 'Comilla': 'G'}
# {'Chittagong': 'B', 'Comilla': 'G', 'Bandarban': 'R'}
# {'Chittagong': 'B', 'Comilla': 'G', 'Bandarban': 'R', 'Khagrachari': 'B'}
# {'Chittagong': 'B', 'Comilla': 'G', 'Bandarban': 'R', 'Khagrachari': 'B', 'Noakhali': 'B'}
# {'Chittagong': 'B', 'Comilla': 'G', 'Bandarban': 'R', 'Khagrachari': 'B', 'Noakhali': 'B', 'Rangamati': 'R'}
# {'Chittagong': 'B', 'Comilla': 'G', 'Bandarban': 'R', 'Khagrachari': 'B', 'Noakhali': 'B', 'Rangamati': 'R', 'Coxs Bazar': 'R'}
# {'Chittagong': 'B', 'Comilla': 'G', 'Bandarban': 'R', 'Khagrachari': 'B', 'Noakhali': 'B', 'Rangamati': 'R', 'Coxs Bazar': 'R', 'Chandpur': 'G'}
# {'Chittagong': 'B', 'Comilla': 'G', 'Bandarban': 'R', 'Khagrachari': 'B', 'Noakhali': 'B', 'Rangamati': 'R', 'Coxs Bazar': 'R', 'Chandpur': 'G', 'Feni': 'R'}
