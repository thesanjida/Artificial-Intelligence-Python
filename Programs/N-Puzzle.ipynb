# %% [markdown]
# ###### To solve a puzzle, you are given an initial state and a goal state.
# ###### Target is to reach goal state from initial state using puzzle rules.
# ######  We can move blank tile only on left, right, up, and down
# ![Capture.JPG](attachment:Capture.JPG)

# %% [markdown]
# # Generate an intial state of NPuzzle

# %%
import numpy as np
import random
def get_state(N):    
    state = [item for item in range(N*N)]
    random.shuffle(state)
    tmp = np.array(state)
    print(tmp.reshape(N,N))
    return state

# %%
get_state(4)
# Out:
# [[13  5  7 10]
#  [12  2  3  4]
#  [ 0 14  9  6]
#  [ 8  1 15 11]]
# [13, 5, 7, 10, 12, 2, 3, 4, 0, 14, 9, 6, 8, 1, 15, 11]

# %% [markdown]
# # Calculate inversion

# %% [markdown]
# Inversion is a pair of tiles that are in the reverse order from where they ought to be. In our case, the bigger number is in front of the smaller one.

# %% [markdown]
# ![Capture.JPG](attachment:Capture.JPG)

# %%
def count_inversion(arr):
    arr = [i for i in arr if i !=0]
    print(arr)
    inversion = []
    for i in range(len(arr)):    
        count = 0
        for j in range(i+1,len(arr)):        
            if(arr[i] > arr[j]): 
                count = count + 1
        inversion.append(count)
    print(inversion)
    return sum(inversion)

# %%
s = get_state(4)
count_inversion(s)
# Out:
# [[ 4 12 14  8]
#  [10  0 15  5]
#  [11  2  3 13]
#  [ 9  6  7  1]]
# [4, 12, 14, 8, 10, 15, 5, 11, 2, 3, 13, 9, 6, 7, 1]
# [3, 10, 11, 6, 7, 9, 3, 6, 1, 1, 4, 3, 1, 1, 0]
# 66

# %% [markdown]
# # Solvability Rules

# %%
N = 5

# %%
S = get_state(N)
# Out:
# [[17  5 22  7 18]
#  [15 12 19 20 14]
#  [ 6 21  9 23  4]
#  [ 3 10  2  8  1]
#  [ 0 16 11 24 13]]

# %%
I = count_inversion(S)
I
# Out:
# [17, 5, 22, 7, 18, 15, 12, 19, 20, 14, 6, 21, 9, 23, 4, 3, 10, 2, 8, 1, 16, 11, 24, 13]
# [16, 4, 19, 5, 14, 12, 9, 12, 12, 10, 4, 10, 5, 9, 3, 2, 3, 1, 1, 0, 2, 0, 1, 0]
# 154

# %%
def get_row(S):
    Blank=0
    index=0
    for i in S:
        if(i==Blank):
            break
        else:
            index+=1
    index
    row_number=(((len(S)-(index+1))//N)+1) 
    return row_number

# %%
R = get_row(S)
R
# Out:
# 1

# %%
def isSolvable(N, I, R):
    if (N%2)!=0 and (I%2)==0 : 
        return True
    elif (N%2)==0 and (I%2)==0 and (R%2)!=0:
        return True
    elif (N%2)==0 and (R%2)==0 and (I%2)!=0 : 
        return True
    else:
        return False

# %%
M= isSolvable(N, I, R)
M
# Out:
# True
